# %%
import random
import nltk
import spacy
from nltk.corpus import wordnet
import re
from googletrans import Translator

# Initialize spaCy Portuguese model
nlp = spacy.load('pt_core_news_sm')

# Download NLTK data files (if not already downloaded)
nltk.download('omw-1.4')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/vanderson/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/vanderson/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# #### getting synonym

# %%
def get_synonyms(word):
    """
    Retrieves synonyms for a Portuguese word using WordNet.
    """
    synsets = wordnet.synsets(word, lang='por')
    synonyms = set()
    for syn in synsets:
        for lemma in syn.lemma_names('por'):
            synonyms.add(lemma.replace('_', ' '))
    synonyms.discard(word)
    return list(synonyms)

# %%
def sinonimo(phrase):
    """
    Replaces words with their synonyms.
    """
    words = phrase.split()
    new_words = []
    for word in words:
        synonyms = get_synonyms(word)
        if synonyms:
            new_word = random.choice(synonyms)
            new_words.append(new_word)
        else:
            new_words.append(word)
    return ' '.join(new_words)

# %%
def word_replacement_thesaurus(phrase):
    """
    Replaces words using a thesaurus (similar to synonyms).
    """
    return sinonimo(phrase)

# %%
def insercao_noise(phrase):
    """
    Introduces insertion noise by randomly adding a word into the phrase.
    """
    words = phrase.split()
    insert_idx = random.randint(0, len(words))
    random_word = random.choice([ 'Casa', 'Carro', 'Computador', 'Livro', 'Árvore', 'Café', 'Amigo', 'Cidade', 'Escola', 'Relógio',
    'Telefone', 'Janela', 'Cadeira', 'Mesa', 'Bicicleta', 'Praia', 'Montanha', 'Rio', 'Cachorro', 'Gato',
    'Céu', 'Estrela', 'Flor', 'Pássaro', 'Noite', 'Dia', 'Sol', 'Lua', 'Chave', 'Porta',
    'Sapato', 'Roupa', 'Caneta', 'Lápis', 'Papel', 'Foto', 'Brinquedo', 'Jogo', 'Chuva', 'Neve',
    'Vento', 'Fogo', 'Terra', 'Mar', 'Avião', 'Navio', 'Trem', 'Ônibus', 'Mercado',

    # Verbos
    'Correr', 'Andar', 'Comer', 'Beber', 'Ler', 'Escrever', 'Dormir', 'Acordar', 'Falar', 'Ouvir',
    'Ver', 'Assistir', 'Pensar', 'Sorrir', 'Rir', 'Chorar', 'Jogar', 'Brincar', 'Estudar', 'Trabalhar',
    'Cantar', 'Dançar', 'Nadar', 'Viajar', 'Cozinhar', 'Limpar', 'Consertar', 'Construir', 'Destruir',
    'Comprar', 'Vender', 'Pagar', 'Ganhar', 'Perder', 'Encontrar', 'Procurar', 'Esperar', 'Ajudar',
    'Ensinar', 'Aprender',

    # Adjetivos
    'Bonito', 'Feio', 'Grande', 'Pequeno', 'Alto', 'Baixo', 'Rápido', 'Lento', 'Feliz', 'Triste',
    'Calmo', 'Agitado', 'Doce', 'Amargo', 'Quente', 'Frio', 'Claro', 'Escuro', 'Novo', 'Velho',
    'Forte', 'Fraco', 'Inteligente', 'Bobo', 'Gentil', 'Cruel', 'Simpático', 'Antipático',
    'Interessante', 'Entediante',

    # Advérbios
    'Rapidamente', 'Devagar', 'Hoje', 'Amanhã', 'Ontem', 'Sempre', 'Nunca', 'Às vezes', 'Frequentemente',
    'Raramente', 'Aqui', 'Lá', 'Dentro', 'Fora', 'Longe', 'Perto', 'Acima', 'Abaixo', 'Juntos',
    'Separadamente', 'Certamente', 'Provavelmente', 'Possivelmente', 'Claramente', 'Obviamente',
    'Sutileza', 'Sem dúvida', 'Sem querer', 'De repente', 'Gradualmente'])
    words.insert(insert_idx, random_word)
    return ' '.join(words)

# %%
def parse_input(data):
    """
    Parses input data and returns a list of phrases.
    """
    phrases = []
    for line in data.strip().split('\n'):
        line = line.strip()
        if line.startswith('-'):
            phrase = line[1:].strip()
            phrases.append(phrase)
    return phrases

# %%
def spelling_errors(phrase):
    """
    Introduces spelling errors by altering characters in random words.
    """
    words = phrase.split()
    if words:
        word_idx = random.randint(0, len(words)-1)
        word = words[word_idx]
        if len(word) > 1:
            char_idx = random.randint(0, len(word)-1)
            random_char = random.choice('abcdefghijklmnopqrstuvwxyz')
            word = word[:char_idx] + random_char + word[char_idx+1:]
            words[word_idx] = word
    return ' '.join(words)

# %%
def remocao_noise(phrase):
    """
    Introduces removal noise by randomly deleting a word from the phrase.
    """
    words = phrase.split()
    if words:
        remove_idx = random.randint(0, len(words)-1)
        del words[remove_idx]
    return ' '.join(words)

# %%
def paraphrase_generation(phrase):
    """
    Generates paraphrases using simple transformation rules.
    """
    # Example: Transforming phrases like "cartão de crédito" to "crédito com cartão"
    if 'de' in phrase:
        parts = phrase.split(' de ')
        if len(parts) == 2:
            return f"{parts[1]} com {parts[0]}"
    return phrase

# %%
def paraphrase_regex(phrase):
    """
    Generates paraphrases using regular expressions.
    """
    # Example: Replace "não é" with "não está"
    phrase = re.sub(r'\bnão é\b', 'não está', phrase)
    return phrase

# %%
def paraphrase_syntax_tree(phrase):
    """
    Generates paraphrases by transforming syntax trees.
    """
    doc = nlp(phrase)
    # Simple example: Swap subject and object if possible
    tokens = [token.text for token in doc]
    if len(tokens) >= 3:
        tokens[0], tokens[2] = tokens[2], tokens[0]
        return ' '.join(tokens)
    return phrase

# %%
def back_translation_api(phrase, src_lang='pt', intermediate_lang='en'):
    """
    Gera uma paráfrase através da retrotradução usando o Google Translate.

    Args:
        phrase (str): A frase em português a ser traduzida.
        src_lang (str): Código do idioma de origem (padrão 'pt' para português).
        intermediate_lang (str): Código do idioma intermediário (padrão 'en' para inglês).

    Returns:
        str: A frase retrotraduzida para o português.
    """
    translator = Translator()
    
    try:
        # Traduzir do idioma de origem para o idioma intermediário
        translated = translator.translate(phrase, src=src_lang, dest=intermediate_lang)
        intermediate_text = translated.text
        print(f"Traduzido para {intermediate_lang}: {intermediate_text}")
        
        # Traduzir de volta para o idioma de origem
        back_translated = translator.translate(intermediate_text, src=intermediate_lang, dest=src_lang)
        final_text = back_translated.text
        print(f"Retrotraduzido para {src_lang}: {final_text}")
        
        return final_text
    
    except Exception as e:
        print("Ocorreu um erro durante a retrotradução:", e)
        return phrase  # Retorna a frase original em caso de erro

# %%
data = '''
    - Quais são os métodos de pagamento aceitos?
      - Quais são as formas de pagamento aceitas pela clínica?
      - tipos de pagamento são aceitos?
      - tipos de pagamento estão disponíveis?
      - Voces aceitam cartão de crédito?
      - Voces aceitam cartão de débito?
      - Aceitam cartão de crédito?
      - Aceitam cartão de débito?
      - Voces aceitam Pix?
      - Voces parcelam a consulta?
      - Voces parcelam?
      - Aceitam Pix?
      - Voces aceitam pagamento em dinheiro?
      - pagamento em dinheiro?
'''

phrases = parse_input(data)

# %%
for phrase in phrases:
    print("Original:", phrase)
    print("Inserção (Noise):", insercao_noise(phrase))
    print("Remoção (Noise):", remocao_noise(phrase))
    print("Erros de Ortografia:", spelling_errors(phrase))
    print("Sinônimo:", sinonimo(phrase))
    print("Substituição com Tesauro:", word_replacement_thesaurus(phrase))
    print("Geração de Parágrafo:", paraphrase_generation(phrase))
    print("Paráfrase com Regex:", paraphrase_regex(phrase))
    print("Paráfrase com Árvore Sintática:", paraphrase_syntax_tree(phrase))
    print("Back Translation:", back_translation_api(phrase))
    print("-" * 50)
# Out:
# Original: Quais são os métodos de pagamento aceitos?
# Inserção (Noise): Quais são Rápido os métodos de pagamento aceitos?
# Remoção (Noise): Quais são os de pagamento aceitos?
# Erros de Ortografia: Quais são ok métodos de pagamento aceitos?
# Sinônimo: Quais saudável os método faminto recompensa aceitos?
# Substituição com Tesauro: Quais salubre os método faminto recompensa aceitos?
# Geração de Parágrafo: pagamento aceitos? com Quais são os métodos
# Paráfrase com Regex: Quais são os métodos de pagamento aceitos?
# Paráfrase com Árvore Sintática: os são Quais métodos de pagamento aceitos ?
# Back Translation: aceitos? pagamento de métodos os são Quais
# --------------------------------------------------
# Original: Quais são as formas de pagamento aceitas pela clínica?
# Inserção (Noise): Quais são Noite as formas de pagamento aceitas pela clínica?
# Remoção (Noise): Quais são as formas de pagamento pela clínica?
# Erros de Ortografia: Quais são as formas de pazamento aceitas pela clínica?
# Sinônimo: Quais sã as formas forma recompensa aceitas popa clínica?
# Substituição com Tesauro: Quais mentalmente são as formas alguma recompensa aceitas popa clínica?
# Geração de Parágrafo: pagamento aceitas pela clínica? com Quais são as formas
# Paráfrase com Regex: Quais são as formas de pagamento aceitas pela clínica?
# Paráfrase com Árvore Sintática: as são Quais formas de pagamento aceitas pela clínica ?
# Back Translation: clínica? pela aceitas pagamento de formas as são Quais
# --------------------------------------------------
# Original: tipos de pagamento são aceitos?
# Inserção (Noise): tipos de Escrever pagamento são aceitos?
# Remoção (Noise): tipos de pagamento aceitos?
# Erros de Ortografia: tipos de pagamentm são aceitos?
# Sinônimo: tipos morrendo recompensa mentalmente sadio aceitos?
# Substituição com Tesauro: tipos morrendo recompensa sadio aceitos?
# Geração de Parágrafo: pagamento são aceitos? com tipos
# Paráfrase com Regex: tipos de pagamento são aceitos?
# Paráfrase com Árvore Sintática: pagamento de tipos são aceitos ?
# Back Translation: aceitos? são pagamento de tipos
# --------------------------------------------------
# Original: tipos de pagamento estão disponíveis?
# Inserção (Noise): tipos Navio de pagamento estão disponíveis?
# Remoção (Noise): tipos de pagamento estão
# Erros de Ortografia: tipos de pagamentf estão disponíveis?
# Sinônimo: tipos alguma recompensa estão disponíveis?
# Substituição com Tesauro: tipos esquerda recompensa estão disponíveis?
# Geração de Parágrafo: pagamento estão disponíveis? com tipos
# Paráfrase com Regex: tipos de pagamento estão disponíveis?
# Paráfrase com Árvore Sintática: pagamento de tipos estão disponíveis ?
# Back Translation: disponíveis? estão pagamento de tipos
# --------------------------------------------------
# Original: Voces aceitam cartão de crédito?
# Inserção (Noise): Voces aceitam Cozinhar cartão de crédito?
# Remoção (Noise): Voces cartão de crédito?
# Erros de Ortografia: Voces aceitam vartão de crédito?
# Sinônimo: Voces aceitam cartas geográficas ferramentas crédito?
# Substituição com Tesauro: Voces aceitam cartas geográficas estar crédito?
# Geração de Parágrafo: crédito? com Voces aceitam cartão
# Paráfrase com Regex: Voces aceitam cartão de crédito?
# Paráfrase com Árvore Sintática: cartão aceitam Voces de crédito ?
# Back Translation: crédito? de cartão aceitam Voces
# --------------------------------------------------
# Original: Voces aceitam cartão de débito?
# Inserção (Noise): Papel Voces aceitam cartão de débito?
# Remoção (Noise): Voces aceitam cartão débito?
# Erros de Ortografia: Voces aceitam cvrtão de débito?
# Sinônimo: Voces aceitam papelão fome débito?
# Substituição com Tesauro: Voces aceitam papelão morrendo débito?
# Geração de Parágrafo: débito? com Voces aceitam cartão
# Paráfrase com Regex: Voces aceitam cartão de débito?
# Paráfrase com Árvore Sintática: cartão aceitam Voces de débito ?
# Back Translation: débito? de cartão aceitam Voces
# --------------------------------------------------
# Original: Aceitam cartão de crédito?
# Inserção (Noise): Aceitam Árvore cartão de crédito?
# Remoção (Noise): Aceitam de crédito?
# Erros de Ortografia: Aceitam cartão xe crédito?
# Sinônimo: Aceitam papelão estar crédito?
# Substituição com Tesauro: Aceitam carta de esquerda crédito?
# Geração de Parágrafo: crédito? com Aceitam cartão
# Paráfrase com Regex: Aceitam cartão de crédito?
# Paráfrase com Árvore Sintática: de cartão Aceitam crédito ?
# Back Translation: crédito? de cartão Aceitam
# --------------------------------------------------
# Original: Aceitam cartão de débito?
# Inserção (Noise): Novo Aceitam cartão de débito?
# Remoção (Noise): Aceitam cartão débito?
# Erros de Ortografia: Aceitam cartão de débits?
# Sinônimo: Aceitam carta apostas débito?
# Substituição com Tesauro: Aceitam papelão de esquerda débito?
# Geração de Parágrafo: débito? com Aceitam cartão
# Paráfrase com Regex: Aceitam cartão de débito?
# Paráfrase com Árvore Sintática: de cartão Aceitam débito ?
# Back Translation: débito? de cartão Aceitam
# --------------------------------------------------
# Original: Voces aceitam Pix?
# Inserção (Noise): Velho Voces aceitam Pix?
# Remoção (Noise): aceitam Pix?
# Erros de Ortografia: qoces aceitam Pix?
# Sinônimo: Voces aceitam Pix?
# Substituição com Tesauro: Voces aceitam Pix?
# Geração de Parágrafo: Voces aceitam Pix?
# Paráfrase com Regex: Voces aceitam Pix?
# Paráfrase com Árvore Sintática: Pix aceitam Voces ?
# Back Translation: Pix? aceitam Voces
# --------------------------------------------------
# Original: Voces parcelam a consulta?
# Inserção (Noise): Estrela Voces parcelam a consulta?
# Remoção (Noise): Voces parcelam a
# Erros de Ortografia: Voces parcelam a cgnsulta?
# Sinônimo: Voces parcelam a consulta?
# Substituição com Tesauro: Voces parcelam a consulta?
# Geração de Parágrafo: Voces parcelam a consulta?
# Paráfrase com Regex: Voces parcelam a consulta?
# Paráfrase com Árvore Sintática: a parcelam Voces consulta ?
# Back Translation: consulta? a parcelam Voces
# --------------------------------------------------
# Original: Voces parcelam?
# Inserção (Noise): Fora Voces parcelam?
# Remoção (Noise): Voces
# Erros de Ortografia: Voces parfelam?
# Sinônimo: Voces parcelam?
# Substituição com Tesauro: Voces parcelam?
# Geração de Parágrafo: Voces parcelam?
# Paráfrase com Regex: Voces parcelam?
# Paráfrase com Árvore Sintática: ? parcelam Voces
# Back Translation: parcelam? Voces
# --------------------------------------------------
# Original: Aceitam Pix?
# Inserção (Noise): Esperar Aceitam Pix?
# Remoção (Noise): Aceitam
# Erros de Ortografia: Acgitam Pix?
# Sinônimo: Aceitam Pix?
# Substituição com Tesauro: Aceitam Pix?
# Geração de Parágrafo: Aceitam Pix?
# Paráfrase com Regex: Aceitam Pix?
# Paráfrase com Árvore Sintática: ? Pix Aceitam
# Back Translation: Pix? Aceitam
# --------------------------------------------------
# Original: Voces aceitam pagamento em dinheiro?
# Inserção (Noise): Voces aceitam pagamento Quente em dinheiro?
# Remoção (Noise): Voces aceitam pagamento em
# Erros de Ortografia: Voces aceitam pagamento em dinleiro?
# Sinônimo: Voces aceitam recompensa diagonal dinheiro?
# Substituição com Tesauro: Voces aceitam recompensa ler dinheiro?
# Geração de Parágrafo: Voces aceitam pagamento em dinheiro?
# Paráfrase com Regex: Voces aceitam pagamento em dinheiro?
# Paráfrase com Árvore Sintática: pagamento aceitam Voces em dinheiro ?
# Back Translation: dinheiro? em pagamento aceitam Voces
# --------------------------------------------------
# Original: pagamento em dinheiro?
# Inserção (Noise): pagamento em Papel dinheiro?
# Remoção (Noise): pagamento em
# Erros de Ortografia: pagamento ew dinheiro?
# Sinônimo: recompensa adentro dinheiro?
# Substituição com Tesauro: recompensa dentro dinheiro?
# Geração de Parágrafo: pagamento em dinheiro?
# Paráfrase com Regex: pagamento em dinheiro?
# Paráfrase com Árvore Sintática: dinheiro em pagamento ?
# Back Translation: dinheiro? em pagamento
# --------------------------------------------------
