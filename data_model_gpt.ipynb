# %%
from openai import OpenAI
import os
import json

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
perguntas = [
    "remarcar consulta",
    "remarcar minha consulta",
    "remarcar a data da consulta",
    "remarcar uma consulta",
    "Quero mudar o dia da minha consulta",
    "Como posso adiar a consulta agendada",
    "É possível reagendar minha consulta",
    "Posso mudar o dia da minha consulta",
    "Preciso antecipar minha consulta",
    "Podem alterar a data da minha consulta",
    "Gostaria de mover minha consulta marcada",
    "Posso alterar o dia da minha consulta",
    "necessito antecipar minha consulta.",
    "Queria perguntar se posso adiantar minha consulta",
    "Por favor, preciso reagendar a consulta",
    "Gostaria de mudar a data da minha consulta",
    "Quero remarcar minha consulta",
    "Como faco pra remarcar a consulta",
    "Tem como remarcar a consulta",
    "Quero adiar a minha consulta",
    "Quero adiantar a minha consulta",
    "Como faco para adiar a minha consulta",
    "mudar o dia da consulta",
    "adiar a consulta",
    "adiantar a consulta",
    "remarcar a consulta",
    "reagendar minha consulta",
    "Quero mudar o dia da minha consulta",
    "Quero alterar o dia da minha consulta",
    "Quero trocar o dia da minha consulta",
    "Posso adiar a consulta agendada",
    "Como posso adiar a consulta agendada",
    "É possível reagendar minha consulta",
    "Posso mudar o dia da minha consulta",
    "Posso alterar o dia da minha consulta",
    "Posso trocar o dia da minha consulta",
    "Desejo antecipar minha consulta",
    "Como posso antecipar minha consulta",
    "Preciso antecipar minha consulta",
    "Posso adiar a consulta agendada",
    "Como posso adiar a consulta agendada",
    "É possível reagendar minha consulta",
    "Posso alterar o dia da minha consulta",
    "Posso mudar a data da minha consulta",
    "Posso reagendar minha consulta",
    "Como posso trocar a data da minha consulta",
    "Posso alterar o horário da minha consulta",
    "É possível adiar minha consulta",
    "Como posso reagendar minha consulta",
    "Como posso mudar a consulta agendada?",
    "É viável mudar a minha consulta ?",
    "Como posso reagendar minha consulta?",
    "Posso mudar a hora da minha consulta?",
    "É possível adiar a consulta?",
    "Posso mudar a data da minha consulta",
    "Como posso trocar o dia da minha consulta ?",
    "Como posso adiar minha consulta marcada ?",
    "Posso reagendar minha consulta para outra data?",
    "É possível alterar o horário da minha consulta?",
    "Como posso mudar a data da minha consulta ?",
    "Posso adiar minha consulta ?",
    "Posso ajustar o horário da minha consulta ?",
    "Como posso mudar minha consulta para outra data?",
    "Posso mudar a minha consulta",
    "Quero mudar a data da minha consulta",
    "Preciso reagendar o dia da minha consulta",
    "Desejo alterar a data da minha consulta",
    "Gostaria de mudar o dia marcado para minha consulta",
    "É necessário modificar a data da minha consulta",
    "Gostaria de ajustar o dia agendado para minha consulta",
    "Necessito modificar o horário da minha consulta",
    "Quero antecipar a data da minha consulta",
    "Preciso alterar o agendamento da minha consulta",
    "Quero reagendar minha consulta",
    "Posso modificar o dia da minha consulta",
    "Gostaria de alterar o dia da minha consulta",
    "Posso reagendar minha consulta para a semana seguinte?",
    "Gostaria de modificar a data da minha consulta",
    "Gostaria de reagendar minha consulta para o mesmo dia",
    "Posso trocar a data da minha consulta",
    "Gostaria de adiar minha consulta",
    "É possível reagendar minha consulta",
    "Posso reagendar minha consulta para o mes que vem?",
    "Posso ajustar a data da minha consulta",
    "Quero alterar a data da minha consulta.",
    "Gostaria de trocar o dia da minha consulta",
    "Posso alterar a data da minha consulta",
    "Gostaria de ajustar o dia da minha consulta",
    "Posso adiar minha consulta para o último dia do mes?",
    "Posso reagendar minha consulta para o próximo mes?",
    "Quero mudar minha consulta",
    "Gostaria de reagendar minha consulta",
    "Gostaria de mudar o dia da minha consulta",
    "Posso alterar a data da minha consulta",
    "Posso mudar o dia da minha consulta",
    "Posso trocar o dia da minha consulta",
    "Necessito adiantar a consulta que tenho",
    "necessito ajustar a data da minha consulta.",
    "preciso reagendar minha consulta para mais cedo.",
    "Necessito mudar a consulta para a primeira hora disponível.",
    "Quero reagendar minha consulta para uma data mais cedo",
    "Quero adiantar a data da minha consulta",
    "Necessito reagendar minha consulta para um momento mais cedo",
    "preciso reagendar minha consulta",
    "Necessito adiantar minha consulta",
    "preciso ajustar a data da minha consulta.",
    "Quero reagendar minha consulta para uma hora mais cedo",
    "Necessito reagendar minha consulta para um horário mais cedo",
    "mudar o dia",
    "mudar o dia da consulta",
    "quero trocar o dia ta consulta",
    "quero remarcar minha consulta",
    "preciso remarcar minha consulta",
]
contexto = "remarcar consulta em uma clínica médica"
resposta = "Deseja remarcar a data da consulta?"

# Lista para armazenar os exemplos formatados
exemplos_formatados = []

for pergunta in perguntas:
    # Formatar o exemplo no formato JSONL esperado
    exemplo = {
        "prompt": f"{contexto}",
        "completion": f" {pergunta}"
    }
    exemplos_formatados.append(exemplo)

# Exibindo o resultado em formato JSON
for exemplo in exemplos_formatados:
    print(json.dumps(exemplo, ensure_ascii=False))
# Out:
# {"prompt": "remarcar consulta em uma clínica médica", "completion": " remarcar consulta"}
# {"prompt": "remarcar consulta em uma clínica médica", "completion": " remarcar minha consulta"}
# {"prompt": "remarcar consulta em uma clínica médica", "completion": " remarcar a data da consulta"}
# {"prompt": "remarcar consulta em uma clínica médica", "completion": " remarcar uma consulta"}
# {"prompt": "remarcar consulta em uma clínica médica", "completion": " Quero mudar o dia da minha consulta"}
# {"prompt": "remarcar consulta em uma clínica médica", "completion": " Como posso adiar a consulta agendada"}
# {"prompt": "remarcar consulta em uma clínica médica", "completion": " É possível reagendar minha consulta"}
# {"prompt": "remarcar consulta em uma clínica médica", "completion": " Posso mudar o dia da minha consulta"}
# {"prompt": "remarcar consulta em uma clínica médica", "completion": " Preciso antecipar minha consulta"}
# ...

# %%
perguntas= [
    "cancelar consulta",
    "cancelar uma consulta",
    "Quero cancelar a consulta.",
    "Como faz para cancelar a consulta?",
    "Preciso cancelar a consulta.",
    "Gostaria de desmarcar a consulta.",
    "Como faço para cancelar a consulta que marquei?",
    "Preciso cancelar meu agendamento.",
    "Quero desfazer o agendamento.",
    "Preciso desmarcar a consulta.",
    "Como posso cancelar uma consulta marcada?",
    "É possível cancelar meu horário?",
    "Posso cancelar a consulta que agendei?",
    "Desejo cancelar o agendamento que fiz",
    "Como posso desmarcar meu agendamento",
    "Como posso cancelar meu horário marcado?",
    "Preciso cancelar meu horário marcado",
    "Gostaria de desfazer a consulta que agendei",
    "Como faço para desmarcar uma consulta que não poderei comparecer?",
    "Como faço para tirar uma consulta que não poderei comparecer?",
    "Gostaria de saber como desfazer um agendamento de consulta",
    "É possível desmarcar uma consulta?",
    "Preciso desmarcar minha consulta",
    "Preciso tirar minha consulta",
    "Preciso cancelar minha consulta",
    "Como cancelar uma consulta",
    "Quero cancelar a consulta",
    "Como faz para cancelar a consulta",
    "Preciso cancelar a consulta",
    "gostaria de desmarcar a consulta",
    "quero desmarcar que fiz",
    "como faço para cancelar a consulta que marquei",
    "preciso cancelar meu agendamento",
    "quero desfazer o agendamento de uma consulta",
    "preciso desmarcar a consulta",
    "como posso cancelar uma consulta marcada",
    "é possível cancelar meu horário?",
    "posso cancelar a consulta que agendei",
    "desejo cancelar o agendamento que fiz",
    "Como posso desmarcar meu agendamento",
    "Gostaria de desfazer a consulta que agendei",
    "Estou precisando cancelar minha sessão agendada",
    "Como faço para desmarcar uma consulta que não poderei comparecer?",
    "É possível desmarcar uma consulta",
    "preciso desmarcar minha consulta de amanhã.",
    "Como posso desfazer a reserva da minha consulta",
    "necessito cancelar todas as minhas consultas agendadas",
    "Queria cancelar uma consulta agendada",
    "Como posso cancelar minha consulta",
    "Quero cancelar a consulta.",
    "Como faz para cancelar a consulta?",
    "preciso cancelar a consulta",
    "Gostaria de desmarcar a consulta",
    "quero desmarcar que fiz",
    "como faço para cancelar a consulta que marquei",
    "preciso cancelar meu agendamento",
    "quero desfazer o agendamento de uma consulta",
    "preciso desmarcar a consulta",
    "como posso cancelar uma consulta marcada",
    "é possível cancelar meu horário?",
    "posso cancelar a consulta que agendei",
    "desejo cancelar o agendamento que fiz",
    "Como posso desmarcar meu agendamento",
    "Gostaria de desfazer a consulta que agendei",
    "Estou precisando cancelar minha sessão agendada",
    "Como faço para desmarcar uma consulta que não poderei comparecer?",
    "É possível desmarcar uma consulta",
    "preciso desmarcar minha consulta de amanhã.",
    "Como posso desfazer a reserva da minha consulta",
    "necessito cancelar todas as minhas consultas agendadas",
    "Queria cancelar uma consulta agendada",
    "Como posso cancelar minha consulta"
]
contexto = "cancelar o agendamento de uma consulta em uma clinica medica"
resposta = "Voce deseja cancelar sua consulta agendada conosco?"
exemplos_formatados = []

for pergunta in perguntas:
    # Formatar o exemplo no formato JSONL esperado
    exemplo = {
        "prompt": f"{contexto}",
        "completion": f" {pergunta}"
    }
    exemplos_formatados.append(exemplo)

# Exibindo o resultado em formato JSON
for exemplo in exemplos_formatados:
    print(json.dumps(exemplo, ensure_ascii=False))
# Out:
# {"prompt": "cancelar o agendamento de uma consulta em uma clinica medica", "completion": " cancelar consulta"}
# {"prompt": "cancelar o agendamento de uma consulta em uma clinica medica", "completion": " cancelar uma consulta"}
# {"prompt": "cancelar o agendamento de uma consulta em uma clinica medica", "completion": " Quero cancelar a consulta."}
# {"prompt": "cancelar o agendamento de uma consulta em uma clinica medica", "completion": " Como faz para cancelar a consulta?"}
# {"prompt": "cancelar o agendamento de uma consulta em uma clinica medica", "completion": " Preciso cancelar a consulta."}
# {"prompt": "cancelar o agendamento de uma consulta em uma clinica medica", "completion": " Gostaria de desmarcar a consulta."}
# {"prompt": "cancelar o agendamento de uma consulta em uma clinica medica", "completion": " Como faço para cancelar a consulta que marquei?"}
# ...

# %%
perguntas = [
    "bom dia",
"boa tarde",
"Boa noite",
"Oi, tudo bem?",
"Ola, como vai?",
"E aí,",
"aí, E beleza?",
"E aí, beleza?",
"Oi",
"Oi, boa tarde!",
"bom noite, como estão as coisas?",
"Ola",
"Oi como esta",
"Oi, tudo bem?",
"Ola, como vai?",
"Boa tarde, tudo certo?",
"E aí, beleza?",
"oi, boa tarde!",
"Boa noite, como estão as coisas?",
"olá",
"bom dia",
"boa tarde",
"boa noite",
"Oi, tudo bem?",
"Olá, como vai?",
"Oi",
"E aí?",
"E aí, beleza?",
"Oi, boa tarde!",
"bom dia, como estão as coisas?",
"boa noite, tudo certo?",
"olá",
"Oi, como você está?",
"tudo bem?",
"boa tarde, tudo certo?",
"E aí, tudo bem?",
"boa noite, tudo bem com você?",
"olá, tudo certo?",
"Oi, como vai?",
"oi, tudo certo?",
"Oi, como está indo?",
"boa tarde, como estão as coisas?",
"bom dia, tudo tranquilo?",
"E aí, como você está?",
"Oi, tudo tranquilo?",
"Olá, tudo bem por aí?",
"Oi, beleza?",
"olá, tudo certo?",
"bom dia, como você está?",
"boa tarde, tudo bem por aí?",
"Olá, como estão as coisas?",
"Oi, tudo certo com você?",
"Olá, como vai o dia?",
"E aí, como você está indo?",
"Oi, tudo ok?",
"bom dia, tudo certo?",
"boa tarde, como está?",
"Olá, como estão as coisas por aí?",
"Oi, tudo tranquilo contigo?",
"Oi, como vai seu dia?",
"boa noite, tudo tranquilo?",
"Oi, como vai tudo?",
"Oi, tudo em ordem?",
"E aí, beleza com você?",
"Oi, como vai sua tarde?",
"bom dia, tudo bem por aí?",
"boa tarde, tudo certo com você?",
"Oi, tudo tranquilo por aí?",
"Oi, tudo bem com você?",
"Olá, tudo bem como está?",
"E aí, tudo certo?",
"Olá, como está o dia?",
"oi, tudo certo com você?",
"boa tarde, como vai o dia?",
"bom dia, como você está hoje?",
"Oi, como estão as coisas com você?",
"boa tarde, tudo certo com as coisas?",
"Oi, beleza por aí?",
"Olá, tudo certo por aí?",
"boa tarde, tudo tranquilo contigo?",
"Oi, tudo bem hoje?",
"Olá, tudo bem por aqui?",
"E aí, beleza com você hoje?",
"boa noite, tudo em ordem?",
"Oi, tudo certo aí?",
"bom dia, tudo tranquilo com você?",
"Oi, tudo em ordem por aí?"
]
contexto = "saudacoes de um usuario"
resposta = "Olá tudo bem? No que posso ajudar?"

exemplos_formatados = []

for pergunta in perguntas:
    # Formatar o exemplo no formato JSONL esperado
    exemplo = {
        "prompt": f"{contexto}",
        "completion": f" {pergunta}"
    }
    exemplos_formatados.append(exemplo)

# Exibindo o resultado em formato JSON
for exemplo in exemplos_formatados:
    print(json.dumps(exemplo, ensure_ascii=False))
# Out:
# {"prompt": "saudacoes de um usuario", "completion": " bom dia"}
# {"prompt": "saudacoes de um usuario", "completion": " boa tarde"}
# {"prompt": "saudacoes de um usuario", "completion": " Boa noite"}
# {"prompt": "saudacoes de um usuario", "completion": " Oi, tudo bem?"}
# {"prompt": "saudacoes de um usuario", "completion": " Ola, como vai?"}
# {"prompt": "saudacoes de um usuario", "completion": " E aí,"}
# {"prompt": "saudacoes de um usuario", "completion": " aí, E beleza?"}
# {"prompt": "saudacoes de um usuario", "completion": " E aí, beleza?"}
# {"prompt": "saudacoes de um usuario", "completion": " Oi"}
# {"prompt": "saudacoes de um usuario", "completion": " Oi, boa tarde!"}
# {"prompt": "saudacoes de um usuario", "completion": " bom noite, como estão as coisas?"}
# {"prompt": "saudacoes de um usuario", "completion": " Ola"}
# {"prompt": "saudacoes de um usuario", "completion": " Oi como esta"}
# {"prompt": "saudacoes de um usuario", "completion": " Oi, tudo bem?"}
# ...

# %%
perguntas = [
"Quais são as formas de pagamento disponíveis?",
"são as formas de pagamento?",
"Quais são as opções de pagamento disponíveis?",
"opções de pagamento?",
"Quais formas de pagamento estão disponíveis?",
"Quais formas de pagamento vocês aceitam?",
"métodos de pagamento estão disponíveis?",
"Quais métodos de pagamento vocês aceitam?",
"formas de pagamento aceitas?",
"Quais opções de pagamento vocês oferecem?",
"métodos de pagamento vocês oferecem?",
"Quais são os métodos de pagamento aceitos?",
"Quais são as formas de pagamento aceitas pela clínica?",
"tipos de pagamento são aceitos?",
"tipos de pagamento estão disponíveis?",
"Vocês aceitam cartão de crédito?",
"Vocês aceitam cartão de débito?",
"Aceitam cartão de crédito?",
"Aceitam cartão de débito?",
"Vocês aceitam Pix?",
"Vocês parcelam a consulta?",
"Vocês parcelam?",
"Aceitam Pix?",
"Vocês aceitam pagamento em dinheiro?",
"pagamento em dinheiro?",
"Quais formas de pagamento por cartão vocês aceitam?",
"Aceitam pagamentos em parcelas?",
"Vocês aceitam pagamentos em parcelas?",
"Quais são as formas de parcelamento disponíveis?",
"Vocês aceitam pagamento na entrega?",
"Existe opção de parcelamento?",
"Existem opções de parcelamento?",
"Quais são as opções de parcelamento?",
"Quais são as formas de pagar pela consulta?",
"Quais opções de pagamento para consultas vocês têm?",
"Vocês aceitam cartão de crédito para pagamento da consulta?",
"cartão de crédito?",
"cartão de débito?",
"Aceitam Pix para pagamento da consulta?",
"Posso pagar a consulta com Pix?",
"Posso pagar com dinheiro?",
"Aceitam dinheiro?",
"Quais cartões de crédito são aceitos?",
"Quais cartões de débito são aceitos?",
"Aceitam pagamento por cartão?",
"Posso pagar a consulta em dinheiro?",
"Aceitam pagamento em dinheiro?",
"Vocês aceitam todos os tipos de cartão?",
"Posso pagar a consulta com cartão?",
"Aceitam pagamento em cartão?",
"Aceitam pagamento em dinheiro para consulta?",
"Posso pagar a consulta com dinheiro?",
"Quais são os métodos de pagamento aceitos pela clínica?",
"Posso pagar com cartão de crédito?",
"Aceitam pagamento com cartão de crédito?",
"Posso pagar com cartão de débito?",
"Aceitam pagamento com cartão de débito?",
"Aceitam cartões de crédito?",
"Aceitam cartões de débito?",
"Posso pagar com Pix?",
"Aceitam Pix como forma de pagamento?",
"Vocês aceitam pagamento por Pix?",
"Posso usar Pix para pagar a consulta?",
"Vocês oferecem parcelamento?",
"Aceitam parcelamento?",
"Posso pagar em parcelas?",
"Vocês aceitam pagamento em parcelas?",
"Quais opções de parcelamento estão disponíveis?",
"Vocês aceitam pagamento por cartão de crédito?",
"Aceitam pagamento por cartão de débito?",
"Quais formas de pagamento vocês aceitam?",
"Posso pagar com cartão?",
"Aceitam pagamento com cartão?",
"Posso pagar em dinheiro?",
"Aceitam cartões de débito?",
"Aceitam cartões de crédito?",
"Aceitam pagamento por Pix?",
"Vocês oferecem desconto para pagamento em dinheiro?",
"Existe desconto para pagamento em dinheiro?",
"Vocês aceitam todos os cartões de crédito?",
"Aceitam pagamento com cartão de débito?",
"Vocês aceitam todos os cartões de débito?",
"Aceitam pagamento com Pix?",
"Quais são as formas de pagamento disponíveis?",
"Vocês aceitam cartão de crédito?",
"Existe opção de parcelamento?",
"Como faço para pagar com cartão de débito?",
"Podem me informar os métodos de pagamento?",
"Quais opções de pagamento vocês oferecem?",
"posso usar Pix para fazer o pagamento?",
"Posso dividir o pagamento em mais de uma forma?",
"Como funcionam os pagamentos para serviços?",
"Podem confirmar se meu método de pagamento foi aceito?",
"vocês aceitam cartão?",
"vocês aceitam cartão de crédito?",
"aceitam cartão?",
"aceitam pix?",
"vocês aceitam pix?",
"pix",
"cartão",
"cartão de crédito",
"cartão de débito",
"vocês parcelam",
"vocês parcelam no cartão de crédito",
"em até quantas vezes vocês parcelam no cartão?",
"cartão de crédito",
"cartão de débito",
"cartão",
"o pagamento é na hora?",
"como é o pagamento",
"pagamento"
]
contexto = "usuario perguntando sobre metodos de pagamento"
resposta = "Aceitamos diversas formas de pagamento, incluindo pix, dinheiro, e cartões de débito e crédito, com possibilidade de parcelar em até 3 vezes sem juros"
exemplos_formatados = []

for pergunta in perguntas:
    # Formatar o exemplo no formato JSONL esperado
    exemplo = {
        "prompt": f"{contexto}",
        "completion": f" {pergunta}"
    }
    exemplos_formatados.append(exemplo)

# Exibindo o resultado em formato JSON
for exemplo in exemplos_formatados:
    print(json.dumps(exemplo, ensure_ascii=False))
# Out:
# {"prompt": "usuario perguntando sobre metodos de pagamento", "completion": " Quais são as formas de pagamento disponíveis?"}
# {"prompt": "usuario perguntando sobre metodos de pagamento", "completion": " são as formas de pagamento?"}
# {"prompt": "usuario perguntando sobre metodos de pagamento", "completion": " Quais são as opções de pagamento disponíveis?"}
# {"prompt": "usuario perguntando sobre metodos de pagamento", "completion": " opções de pagamento?"}
# {"prompt": "usuario perguntando sobre metodos de pagamento", "completion": " Quais formas de pagamento estão disponíveis?"}
# {"prompt": "usuario perguntando sobre metodos de pagamento", "completion": " Quais formas de pagamento vocês aceitam?"}
# {"prompt": "usuario perguntando sobre metodos de pagamento", "completion": " métodos de pagamento estão disponíveis?"}
# {"prompt": "usuario perguntando sobre metodos de pagamento", "completion": " Quais métodos de pagamento vocês aceitam?"}
# ...

# %%
perguntas = [
"Quais são os próximos dias disponíveis para agendamento?",
"Que data tem disponível?",
"Que dia tem disponível?",
"Que dia tem agenda livre?",
"Que dia tem horário livre?",
"Qual a data mais próxima livre?",
"Você pode me mostrar as datas disponíveis?",
"Você pode me apresentar as datas disponíveis em breve?",
"Você poderia listar os dias disponíveis nas próximas semanas?",
"Me informe sobre qualquer período livre que tenha nos próximos tempos.",
"Quais são os próximos períodos livres que posso marcar uma consulta?",
"Podem me dizer quais são as próximas datas disponíveis?",
"Eu gostaria de ver as próximas oportunidades para agendar.",
"Quando você tem vagas disponíveis para os próximos dias?",
"Estou procurando dias abertos para consulta nos próximos tempos, você pode ajudar?",
"Pode checar quais são os próximos dias vazios?",
"Quero saber quando são os próximos horários livres.",
"Poderia me informar sobre os próximos espaços disponíveis?",
"Quais são as próximas datas livres para fazer uma reserva?",
"Quais são os próximos períodos livres disponíveis?",
"Pode me informar quais dias estão abertos?",
"Quero uma lista dos dias livres nas próximas semanas.",
"Poderia me mostrar as próximas datas que estão livres para agendamento?",
"Preciso saber quais dias ainda estão disponíveis.",
"Existem vagas nos dias que se aproximam?",
"Que datas estão livres para os próximos dias?",
"Pode verificar quais são os próximos horários desocupados?",
"Estou interessado em saber quais dias estão disponíveis para reserva no próximo mês.",
"Por favor, liste os dias que estão livres para consulta nos próximos dias.",
"Você tem alguma informação sobre dias livres para a próxima semana?",
"Me dê uma ideia dos próximos dias com horários livres.",
"Vocês têm horários disponíveis para uma consulta nos próximos dias?",
"quais horários estão disponíveis?",
"Há algum horário disponível para consulta nesta semana?",
"Gostaria de saber os horários livres para uma consulta nos próximos dias.",
"Quais horários vocês têm livres para agendamento de consultas?",
"Existe algum horário livre para uma consulta amanhã?",
"Poderiam me informar os horários disponíveis para consultas médicas?",
"Quais horários estão abertos para eu agendar uma consulta?",
"quais horários vocês têm para consulta?",
"Vocês poderiam verificar quais horários estão livres para consulta?",
"Quando posso marcar uma consulta nos próximos dias?",
"Quais horários estão disponíveis para a próxima semana?",
"Qual o primeiro dia livre para agendamento?",
"Tem algum horário disponível ainda nesta semana?",
"Pode me dizer quando há um horário livre para consulta?",
"Qual a primeira data aberta para marcar uma consulta?",
"Quando posso agendar a consulta mais cedo possível?",
"Pode verificar os dias disponíveis para agendamento?",
"Qual é o próximo dia disponível para uma consulta médica?",
"Gostaria de saber quando posso agendar uma consulta.",
"Quais dias você tem disponíveis para consulta?",
"Qual é a data mais próxima para agendar uma consulta?",
"Quando posso marcar uma consulta no futuro próximo?",
"Quais são os horários disponíveis nos próximos dias?",
"Qual é o dia mais rápido para uma consulta disponível?",
"Quais são as opções de datas disponíveis para consulta?",
"Existe algum dia livre para agendamento esta semana?",
"Você pode me mostrar os horários de consulta disponíveis?",
"Posso saber quais são os dias livres para uma consulta?",
"Quais datas você tem livres para agendar consulta?",
"Tem algum horário de consulta para essa semana?",
"Pode me informar sobre os próximos dias abertos para consulta?",
"Preciso saber quais datas estão livres para agendamento.",
"Quais dias da próxima semana estão disponíveis para consulta?",
"Qual é o próximo horário disponível para marcar consulta?",
"Quando há disponibilidade para marcar uma consulta médica?",
"Preciso agendar uma consulta, quais datas você tem livres?",
"Quando posso marcar a consulta mais próxima possível?",
"Você tem horários livres para os próximos dias?",
"Quando é o próximo horário vago para uma consulta?",
"Qual o primeiro dia livre para consulta médica?",
"Pode listar os horários disponíveis para agendar uma consulta?",
"Qual a primeira data livre para agendar uma consulta médica?",
"Quais dias estão disponíveis para consulta na próxima semana?",
"Pode me mostrar as datas livres para consulta?",
"Existe alguma data disponível ainda este mês?",
"Quais são os próximos horários livres para agendar consulta?",
"Pode me informar sobre os dias abertos para consulta?",
"Quando posso agendar a consulta mais cedo disponível?",
"Tem alguma data livre para consulta nas próximas semanas?",
"Quais horários posso escolher para marcar uma consulta?",
"Qual é o horário de consulta disponível mais próximo?",
"Preciso saber quando você tem horários livres para agendamento.",
"Tem alguma vaga disponível para consulta nesta semana?",
"Quais dias da semana você tem horários disponíveis para consulta?",
"Quando você tem horários livres para consulta nas próximas semanas?",
"Qual o dia mais próximo com horários livres para consulta?",
"Pode me dizer quando posso agendar uma consulta médica?",
"Qual é a data mais próxima disponível para consulta?",
"Quando posso marcar a consulta mais breve possível?"

]
contexto = "usuario querendo saber dias disponiveis para agendar uma consulta"
resposta = "Os proximos dias disponiveis são: "
exemplos_formatados = []

for pergunta in perguntas:
    # Formatar o exemplo no formato JSONL esperado
    exemplo = {
        "prompt": f"{contexto}",
        "completion": f" {pergunta}"
    }
    exemplos_formatados.append(exemplo)

# Exibindo o resultado em formato JSON
for exemplo in exemplos_formatados:
    print(json.dumps(exemplo, ensure_ascii=False))
# Out:
# {"prompt": "usuario querendo saber dias disponiveis para agendar uma consulta", "completion": " Quais são os próximos dias disponíveis para agendamento?"}
# {"prompt": "usuario querendo saber dias disponiveis para agendar uma consulta", "completion": " Que data tem disponível?"}
# {"prompt": "usuario querendo saber dias disponiveis para agendar uma consulta", "completion": " Que dia tem disponível?"}
# {"prompt": "usuario querendo saber dias disponiveis para agendar uma consulta", "completion": " Que dia tem agenda livre?"}
# {"prompt": "usuario querendo saber dias disponiveis para agendar uma consulta", "completion": " Que dia tem horário livre?"}
# {"prompt": "usuario querendo saber dias disponiveis para agendar uma consulta", "completion": " Qual a data mais próxima livre?"}
# {"prompt": "usuario querendo saber dias disponiveis para agendar uma consulta", "completion": " Você pode me mostrar as datas disponíveis?"}
# ...

# %%
perguntas = [
"pode ser",
"pode sim",
"quero sim",
"exatamente",
"isso mesmo",
"claro",
"claro que sim",
"com certeza",
"quero sim",
"desejo sim",
"s",
"ss",
"sim",
"isso",
"sou sim",
"sou",
"Com certeza",
"Claro que sim",
"Absolutamente",
"Sim, por favor",
"Concordo",
"Claro",
"sss",
"Ótimo",
"Óptimo",
"Pode ser",
"Sim, pode",
"Pode sim",
"Sim, claro",
"Melhor ainda",
"Concordo",
"Claro",
"Claro que sim",
"Com certeza",
"Claro",
"Sim",
"ja sim",
"Sim, gostaria de agendar.",
"Com certeza, quero agendar.",
"Sim, eu desejo agendar.",
"Claro, pode agendar pra mim.",
"Sim, quero marcar sim.",
"Sim, desejo agendar.",
"Sim, quero agendar a consulta.",
"Claro, pode agendar.",
"Sim, quero sim.",
"Sim, desejo marcar a consulta.",
"Com certeza, pode agendar.",
"Sim, já quero agendar.",
"Sim, desejo marcar.",
"Sim, por favor, agende.",
"Pode marcar, sim.",
"Sim, quero remarcar a consulta.",
"Sim, pode remarcar a data da consulta.",
"Com certeza, quero remarcar.",
"Sim, preciso remarcar a consulta.",
"Sim, pode remarcar, por favor.",
"Sim, quero sim remarcar.",
"Claro, pode remarcar a consulta.",
"Sim, desejo remarcar a consulta.",
"Sim, por favor, remarque para mim.",
"Sim, quero cancelar a consulta agendada.",
"Pode cancelar minha consulta sim.",
"Sim, eu desejo cancelar.",
"Sim, cancele minha consulta, por favor.",
"Sim, desejo cancelar a consulta.",
"Sim, pode cancelar a consulta.",
"Sim, quero cancelar a consulta agendada.",
"Sim, já tenho cadastro com vocês.",
"Sim, estou cadastrado com vocês.",
"Sim, tenho cadastro.",
"Sim, já tenho cadastro sim.",
"Sim, eu já sou cadastrado.",
"Sim, sou cadastrado na plataforma.",
"Sim, já possuo cadastro com vocês.",
"Sim, já estou cadastrado.",
"Sim, já estou registrado com vocês.",
"Sim, podem checar, já tenho cadastro.",
"Sim, estou sim cadastrado.",
"Sim, quero marcar uma consulta.",
"Sim, desejo marcar uma consulta.",
"Sim, pode marcar a consulta.",
"Sim, desejo marcar agora.",
"Sim, quero marcar a consulta com vocês.",
"Sim, por favor, marque a consulta.",
"Sim, desejo marcar a consulta com vocês.",
"Sim, pode marcar uma consulta pra mim."


]
contexto = "usuario concordando sobre os seguintes temas: querer marcar consulta, remarcar consulta, ser cadastrado, cancelar consulta"
resposta = "ok"
exemplos_formatados = []

for pergunta in perguntas:
    # Formatar o exemplo no formato JSONL esperado
    exemplo = {
        "prompt": f"{contexto}",
        "completion": f" {pergunta}"
    }
    exemplos_formatados.append(exemplo)

# Exibindo o resultado em formato JSON
for exemplo in exemplos_formatados:
    print(json.dumps(exemplo, ensure_ascii=False))
# Out:
# {"prompt": "usuario concordando sobre os seguintes temas: querer marcar consulta, remarcar consulta, ser cadastrado, cancelar consulta", "completion": " pode ser"}
# {"prompt": "usuario concordando sobre os seguintes temas: querer marcar consulta, remarcar consulta, ser cadastrado, cancelar consulta", "completion": " pode sim"}
# {"prompt": "usuario concordando sobre os seguintes temas: querer marcar consulta, remarcar consulta, ser cadastrado, cancelar consulta", "completion": " quero sim"}
# {"prompt": "usuario concordando sobre os seguintes temas: querer marcar consulta, remarcar consulta, ser cadastrado, cancelar consulta", "completion": " exatamente"}
# {"prompt": "usuario concordando sobre os seguintes temas: querer marcar consulta, remarcar consulta, ser cadastrado, cancelar consulta", "completion": " isso mesmo"}
# {"prompt": "usuario concordando sobre os seguintes temas: querer marcar consulta, remarcar consulta, ser cadastrado, cancelar consulta", "completion": " claro"}
# ...

# %%
perguntas = [
"Gostaria de falar com um atendente, por favor.",
"Você pode me transferir para o atendimento humano?",
"Preciso falar com um atendente agora.",
"Me conecte com um atendente, por favor.",
"Como posso falar com um atendente?",
"Quero ser transferido para um atendente humano.",
"Por favor, passe minha solicitação para um atendente.",
"Pode me transferir para o suporte humano?",
"Preciso falar com alguém do suporte ao cliente.",
"Há como falar com um atendente diretamente?",
"Por favor, me transfira para um atendente real.",
"Quero falar com uma pessoa, pode me transferir?",
"Como faço para falar com um atendente?",
"Pode me colocar em contato com um atendente?",
"Gostaria de falar diretamente com alguém do suporte.",
"Você pode me passar para o atendimento humano?",
"Preciso de um atendente, pode transferir?",
"Quero falar com um atendente, por favor.",
"Me conecte com alguém do atendimento, por favor.",
"Pode transferir essa conversa para um atendente humano?",
"Quero ser atendido por uma pessoa, pode me transferir?",
"Me transfira para um atendente humano, por favor.",
"Há como falar com uma pessoa do suporte?",
"Preciso de ajuda de um atendente, por favor.",
"Você pode me transferir para um atendente real?",
"Como posso falar com uma pessoa do suporte?",
"Por favor, passe minha solicitação para um atendente humano.",
"Quero ser transferido para alguém do suporte.",
"Pode me passar para o atendimento humano?",
"Preciso falar diretamente com alguém do suporte.",
"Você pode me conectar com um atendente?",
"Me conecte com um ser humano, por favor.",
"Gostaria de falar com um atendente humano.",
"Pode me transferir para alguém do atendimento ao cliente?",
"Como faço para ser transferido para um atendente?",
"Preciso falar com um atendente humano agora.",
"Há como falar com um atendente de verdade?",
"Quero falar com um atendente real, por favor.",
"Você pode me conectar com um atendente humano?",
"Me passe para um atendente, por favor.",
"Preciso de um atendente, pode me ajudar?",
"Gostaria de ser transferido para um atendente humano.",
"Pode me colocar em contato com uma pessoa?",
"Quero falar com um atendente ao vivo, pode transferir?",
"Você pode me passar para um atendente humano?",
"Como posso falar com um atendente humano?",
"Preciso de um atendente real, por favor.",
"Me transfira para um atendente humano.",
"Pode transferir essa conversa para alguém do suporte?",
"Quero ser atendido por uma pessoa do suporte.",
"Me conecte com alguém do atendimento ao cliente.",
"Você pode me passar para o atendimento ao cliente?",
"Preciso de ajuda de uma pessoa do suporte.",
"Como faço para falar com um atendente real?",
"Quero falar com uma pessoa do suporte ao cliente.",
"Pode me transferir para um atendente humano agora?",
"Gostaria de falar com alguém do atendimento.",
"Me conecte com um atendente real, por favor.",
"Preciso de um atendente humano, pode me ajudar?",
"Como posso ser transferido para um atendente humano?",
"Você pode me passar para o suporte humano?",
"Quero falar com um atendente ao vivo.",
"Me conecte com um ser humano do suporte.",
"Preciso falar com alguém do atendimento humano.",
"Você pode me transferir para um atendente de verdade?",
"Como faço para ser transferido para um atendente humano?",
"Quero ser atendido por uma pessoa do atendimento.",
"Me transfira para o suporte ao cliente, por favor.",
"Você pode me passar para um atendente ao vivo?",
"Preciso de ajuda de um atendente ao vivo.",
"Como posso falar com uma pessoa do atendimento?",
"Me conecte com uma pessoa do atendimento.",
"Você pode me passar para um ser humano?",
"Preciso de um atendente humano, por favor.",
"Pode me transferir para o atendimento humano ao vivo?",
"Quero falar com um atendente de verdade.",
"Me transfira para o suporte humano, por favor.",
"Como faço para ser atendido por uma pessoa?",
"Pode me conectar com um atendente humano?",
"Preciso falar com alguém do suporte humano.",
"Me conecte com um atendente ao vivo.",
"Quero ser transferido para o suporte ao cliente.",
"Pode me transferir para um ser humano?",
"Como posso falar com um atendente real?",
"Preciso de ajuda de uma pessoa do atendimento.",
"Me transfira para o atendimento humano.",
"Pode me passar para o suporte ao cliente?",
"Quero falar com um atendente humano ao vivo.",
"Me conecte com alguém do suporte humano.",
"Você pode me passar para um atendente ao vivo?",
"Preciso falar com uma pessoa do suporte humano.",
"Como faço para ser transferido para um atendimento humano?",
"Quero falar com um atendente real.",
"Me transfira para o atendimento ao cliente, por favor.",
"Pode me conectar com alguém do suporte ao cliente?"


]
contexto = "usuario querendo ser transferido para atendimento humano"
resposta = "Estamos te transferindo para nosso atendente, aguarde um momento "
exemplos_formatados = []

for pergunta in perguntas:
    # Formatar o exemplo no formato JSONL esperado
    exemplo = {
        "prompt": f"{contexto}",
        "completion": f" {pergunta}"
    }
    exemplos_formatados.append(exemplo)

# Exibindo o resultado em formato JSON
for exemplo in exemplos_formatados:
    print(json.dumps(exemplo, ensure_ascii=False))
# Out:
# {"prompt": "usuario querendo ser transferido para atendimento humano", "completion": " Gostaria de falar com um atendente, por favor."}
# {"prompt": "usuario querendo ser transferido para atendimento humano", "completion": " Você pode me transferir para o atendimento humano?"}
# {"prompt": "usuario querendo ser transferido para atendimento humano", "completion": " Preciso falar com um atendente agora."}
# {"prompt": "usuario querendo ser transferido para atendimento humano", "completion": " Me conecte com um atendente, por favor."}
# {"prompt": "usuario querendo ser transferido para atendimento humano", "completion": " Como posso falar com um atendente?"}
# {"prompt": "usuario querendo ser transferido para atendimento humano", "completion": " Quero ser transferido para um atendente humano."}
# {"prompt": "usuario querendo ser transferido para atendimento humano", "completion": " Por favor, passe minha solicitação para um atendente."}
# ...

# %%
perguntas = [
"marcar consulta",
"marcar uma consulta",
"como agendo uma consulta",
"como agendo um horário com vocês",
"quero marcar uma consulta com vocês",
"como faço para marcar uma consulta com vocês",
"Queria agendar um horário",
"Como posso reservar um horário para consulta?",
"É possível marcar um atendimento?",
"Preciso marcar uma consulta.",
"Quero agendar uma consulta para hoje.",
"Como faço para reservar uma consulta?",
"Gostaria de marcar uma consulta.",
"Preciso de um agendamento para uma consulta",
"Como posso agendar uma consulta",
"Podem agendar uma consulta para mim",
"Como posso proceder para reservar uma consulta",
"Quero agendar uma consulta",
"Como faço para reservar um horário para uma consulta",
"É possível marcar um atendimento?",
"Eu gostaria de marcar uma consulta",
"Preciso de uma consulta",
"Como posso proceder para reservar uma consulta",
"Gostaria de agendar uma consulta médica.",
"Preciso marcar uma consulta.",
"Quero agendar uma consulta.",
"Qual é o procedimento para marcar uma consulta",
"É possível agendar uma consulta",
"Poderia me ajudar a agendar uma consulta médica?",
"Estou procurando marcar uma consulta.",
"Posso reservar um horário para consulta?",
"Gostaria de marcar uma consulta.",
"Quero agendar uma consulta",
"Estou interessado em marcar uma consulta.",
"Pode me orientar sobre como marcar uma consulta",
"Preciso de uma consulta",
"Gostaria de saber como agendar uma consulta",
"Posso marcar uma consulta com a médica",
"Podem agendar uma consulta para mim",
"Estou procurando agendar uma consulta",
"É possível agendar uma consulta",
"Como faço para reservar um horário para uma consulta médica",
"Gostaria de marcar uma consulta, como devo proceder?",
"Como posso marcar uma consulta com a clínica?",
"Preciso de informações sobre como agendar uma consulta.",
"Como agendar uma consulta médica na clínica?",
"Gostaria de saber como posso marcar uma consulta.",
"Qual o processo para agendar uma consulta com vocês?",
"Posso agendar uma consulta para semana que vem?",
"Queria marcar uma consulta para amanhã.",
"Como faço para marcar um horário disponível?",
"Vocês podem agendar uma consulta pra mim?",
"Preciso agendar um horário para consulta.",
"Como posso marcar uma consulta com um médico?",
"Quero agendar um atendimento com vocês.",
"Gostaria de marcar um horário para consulta médica.",
"Como agendar um atendimento na clínica?",
"Pode me ajudar a agendar uma consulta?",
"Tem como agendar uma consulta?",
"Poderiam me informar como faço para agendar uma consulta?",
"Quero marcar uma consulta médica.",
"Como posso fazer para marcar um atendimento?",
"Qual o procedimento para marcar um horário de consulta?",
"Preciso de uma consulta com o médico, como agendar?",
"Como proceder para marcar uma consulta?",
"Poderiam agendar uma consulta para mim?",
"Quero saber como posso marcar uma consulta médica.",
"Qual a melhor maneira de marcar uma consulta com vocês?",
"Como posso agendar uma consulta médica?",
"Tem algum horário disponível para marcar uma consulta?",
"Gostaria de marcar um atendimento na clínica.",
"Preciso marcar uma consulta para hoje, como faço?",
"Quero reservar um horário para atendimento.",
"Como posso agendar uma consulta médica com urgência?",
"Podem me orientar sobre como marcar uma consulta?",
"Tem como marcar uma consulta com vocês?",
"Preciso agendar uma consulta urgente.",
"Quero saber como posso agendar uma consulta para a próxima semana.",
"Como posso reservar uma consulta na clínica?",
"Queria reservar um horário para uma consulta.",
"Como agendar um atendimento com vocês?",
"Preciso saber como marcar uma consulta médica.",
"Quero reservar um horário para a consulta médica.",
"Como posso garantir um horário para consulta?",
"Preciso agendar uma consulta o mais rápido possível.",
"Gostaria de reservar um atendimento.",
"Como faço para marcar uma consulta urgente?",
"Tem algum procedimento para marcar uma consulta médica?",
"Preciso marcar uma consulta para essa semana.",
"Vocês podem me informar como agendar uma consulta?",
"Como faço para reservar um horário na clínica?",
"Tem algum horário para eu marcar uma consulta?",
"Quero agendar um horário disponível para consulta."


]
contexto = "usuario querendo agendar uma consulta em uma clinica medica"
resposta = "Deseja marcar uma consulta conosco?"
exemplos_formatados = []

for pergunta in perguntas:
    # Formatar o exemplo no formato JSONL esperado
    exemplo = {
        "prompt": f"{contexto}",
        "completion": f" {pergunta}"
    }
    exemplos_formatados.append(exemplo)

# Exibindo o resultado em formato JSON
for exemplo in exemplos_formatados:
    print(json.dumps(exemplo, ensure_ascii=False))
# Out:
# {"prompt": "usuario querendo agendar uma consulta em uma clinica medica", "completion": " marcar consulta"}
# {"prompt": "usuario querendo agendar uma consulta em uma clinica medica", "completion": " marcar uma consulta"}
# {"prompt": "usuario querendo agendar uma consulta em uma clinica medica", "completion": " como agendo uma consulta"}
# {"prompt": "usuario querendo agendar uma consulta em uma clinica medica", "completion": " como agendo um horário com vocês"}
# {"prompt": "usuario querendo agendar uma consulta em uma clinica medica", "completion": " quero marcar uma consulta com vocês"}
# {"prompt": "usuario querendo agendar uma consulta em uma clinica medica", "completion": " como faço para marcar uma consulta com vocês"}
# {"prompt": "usuario querendo agendar uma consulta em uma clinica medica", "completion": " Queria agendar um horário"}
# {"prompt": "usuario querendo agendar uma consulta em uma clinica medica", "completion": " Como posso reservar um horário para consulta?"}
# ...

# %%
perguntas = [
"Poderia detalhar quais serviços vocês fornecem?",
"Gostaria de uma descrição dos serviços que vocês disponibilizam.",
"Que serviços sua clínica oferece aos pacientes?",
"Quais são os serviços mais populares que vocês oferecem?",
"Estou curioso sobre os serviços, você pode explicar?",
"Pode listar os serviços de saúde que vocês disponibilizam?",
"Gostaria de saber mais sobre os serviços que vocês oferecem.",
"Poderia me fornecer uma visão geral dos seus serviços médicos?",
"Pode me explicar os diferentes tipos de consultas que vocês oferecem?",
"Que tipos de serviços de saúde vocês prestam?",
"Quais tratamentos específicos vocês disponibilizam?",
"Eu gostaria de saber mais sobre os programas que vocês conduzem.",
"Poderia listar todos os serviços médicos que vocês oferecem?",
"Como funciona a clínica?",
"Me fale mais sobre as especialidades da clínica.",
"Gostaria de uma descrição dos serviços que vocês disponibilizam.",
"Quero saber quais são os procedimentos disponíveis.",
"Que serviços sua clínica oferece aos pacientes?",
"Quais são os serviços mais populares que vocês oferecem?",
"Estou curioso sobre os serviços, você pode explicar?",
"Quais tratamentos vocês oferecem para condições específicas?",
"Pode listar os serviços de saúde que vocês disponibilizam?",
"Que tipo de consultas vocês proporcionam?",
"Poderia me fornecer uma visão geral dos seus serviços médicos?",
"Estou interessado nos serviços que vocês disponibilizam.",
"Estou interessado nos serviços terapêuticos disponíveis.",
"Pode descrever as várias opções de serviço que sua clínica possui?",
"Gostaria de conhecer os serviços que vocês oferecem, como funcionam?",
"Pode me dar uma visão geral das consultas especializadas que vocês têm?",
"Quais são as suas principais ofertas de serviços de saúde mental?",
"Quero informações detalhadas sobre os serviços de diagnóstico que vocês têm.",
"Como funciona a clínica?",
"Que profissionais vocês têm na clínica?",
"Que tipo de consulta tem na clínica?",
"Vocês têm psicólogo?",
"Vocês têm qual médico?",
"Vocês têm quais psicólogos?",
"Qual médico psiquiatra vocês têm?",
"Quais serviços médicos vocês oferecem na clínica?",
"Gostaria de saber quais tipos de serviços estão disponíveis.",
"Que tratamentos a clínica disponibiliza?",
"Quais são os serviços que a clínica oferece aos pacientes?",
"Vocês podem me dizer quais são os serviços de saúde disponíveis?",
"Quais especialidades médicas estão disponíveis na clínica?",
"O que a clínica oferece em termos de serviços médicos?",
"Quais são os principais serviços de saúde da clínica?",
"Quais tratamentos posso encontrar na clínica?",
"Gostaria de saber mais sobre os serviços da clínica.",
"Que tipo de atendimento vocês prestam na clínica?",
"Vocês oferecem serviços de saúde mental?",
"Quais são os serviços especializados oferecidos pela clínica?",
"Que serviços médicos estão à disposição dos pacientes?",
"Quais são os procedimentos médicos disponíveis na clínica?",
"Quais serviços são oferecidos para consultas médicas?",
"Posso saber quais tipos de consulta a clínica oferece?",
"Quais tratamentos e exames são oferecidos pela clínica?",
"Vocês têm algum serviço especializado em saúde feminina?",
"Que tipos de serviços clínicos estão disponíveis?",
"Quais tratamentos a clínica tem para oferecer?",
"Vocês podem me dar detalhes sobre os serviços prestados?",
"Quais especialidades médicas posso encontrar na clínica?",
"A clínica oferece serviços de fisioterapia?",
"Quais são os serviços mais procurados da clínica?",
"O que a clínica disponibiliza em termos de consultas?",
"Quais tipos de consultas médicas vocês fazem?",
"Vocês têm serviços de diagnóstico por imagem?",
"Quais são os serviços médicos mais comuns na clínica?",
"Gostaria de saber mais sobre os procedimentos médicos disponíveis.",
"Quais tratamentos para dor a clínica oferece?",
"A clínica oferece serviços de nutrição?",
"Vocês têm serviços de odontologia?",
"Quais são os serviços de apoio à saúde mental na clínica?",
"Vocês fazem exames laboratoriais na clínica?",
"Posso saber quais serviços clínicos vocês prestam?",
"Quais são os serviços médicos disponíveis para atendimento?",
"Vocês fazem exames de rotina na clínica?",
"Que tipos de especialidades médicas estão disponíveis para consultas?",
"Vocês oferecem consultas com especialistas em cardiologia?",
"A clínica tem serviços de pediatria?",
"Quais serviços vocês disponibilizam para pacientes em tratamento?",
"Quais tratamentos médicos são feitos na clínica?",
"Vocês oferecem algum serviço de emergência médica?",
"Quais são os procedimentos médicos oferecidos na clínica?",
"Quais serviços de prevenção e cuidados de saúde vocês oferecem?",
"A clínica oferece consultas com especialistas?",
"Vocês têm algum serviço especializado em ortopedia?",
"Quais exames podem ser realizados na clínica?"


]
contexto = "usuario querendo se informar melhor sobre os servicos oferecidos por uma clinica"
resposta = "Aqui na clínica, temos diversos tipos de atendimento: desde terapia individual até sessões com psiquiatra, psicólogo, terapias comportamentais e até psicoterapia online"
for pergunta in perguntas:
    # Formatar o exemplo no formato JSONL esperado
    exemplo = {
        "prompt": f"{contexto}",
        "completion": f" {pergunta}"
    }
    exemplos_formatados.append(exemplo)

# Exibindo o resultado em formato JSON
for exemplo in exemplos_formatados:
    print(json.dumps(exemplo, ensure_ascii=False))
# Out:
# {"prompt": "usuario querendo ser transferido para atendimento humano", "completion": " Gostaria de falar com um atendente, por favor."}
# {"prompt": "usuario querendo ser transferido para atendimento humano", "completion": " Você pode me transferir para o atendimento humano?"}
# {"prompt": "usuario querendo ser transferido para atendimento humano", "completion": " Preciso falar com um atendente agora."}
# {"prompt": "usuario querendo ser transferido para atendimento humano", "completion": " Me conecte com um atendente, por favor."}
# {"prompt": "usuario querendo ser transferido para atendimento humano", "completion": " Como posso falar com um atendente?"}
# {"prompt": "usuario querendo ser transferido para atendimento humano", "completion": " Quero ser transferido para um atendente humano."}
# {"prompt": "usuario querendo ser transferido para atendimento humano", "completion": " Por favor, passe minha solicitação para um atendente."}
# ...
